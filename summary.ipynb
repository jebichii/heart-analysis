# %% [markdown]
# # 💓 Heart Disease Prediction Using Machine Learning
# *Empowering Early Diagnosis Aligned with UN SDG 3: Good Health and Well-being*
#
# ---
#
# ## 🧠 Project Overview
#
# In pursuit of **SDG 3: Good Health and Well-being**, this project applies machine learning techniques to detect early signs of heart disease—one of the world’s leading causes of death. By supporting early intervention through predictive analytics, the solution aims to reduce preventable mortality and support equitable access to healthcare services.
#
# ---
#
# ## 🌍 The Problem
#
# Cardiovascular diseases are responsible for an estimated **17.9 million deaths annually**. Many of these are preventable through early diagnosis and affordable screening. Yet, in numerous low- and middle-income regions, access to accurate diagnostic tools is limited—hindering timely treatment. This challenge is directly targeted by **SDG 3** and **SDG 10: Reduced Inequalities**.
#
# ---
#
# ## 💡 The Solution: Intelligent Screening with Machine Learning
#
# Using a publicly available dataset (`heart.csv`), I developed an end-to-end machine learning pipeline designed for scalable health screening:
#
# - **Data Preprocessing**: Cleaned and encoded clinical indicators such as age, chest pain type, blood pressure, cholesterol levels, etc.
# - **Model Training**: Applied a robust **Random Forest Classifier** to learn predictive patterns
# - **Evaluation**: Achieved strong metrics including high accuracy, F1-score, and low mean absolute error
# - **Interpretability**: Visualized key risk factors (e.g., ST_Slope, ExerciseAngina) and confusion matrix for transparent model reporting
#
# This pipeline serves as a lightweight and portable **diagnostic assistant**—particularly valuable in regions where expert cardiologists may not be readily accessible.
#
# ---
# ---
# ## 🧩 Ethical Layer
#
# To minimize algorithmic bias and promote fairness:
#
# - Encoded demographic features (e.g., sex, chest pain type) cautiously to avoid model overfitting or skewed predictions
# - Evaluated model performance across subgroups (e.g., gender)
#
# ---
#
# ## 🔍 Key Concepts Utilized
#
# - **Supervised Learning**
#   Labeled heart data trains classification models to distinguish between patients with and without heart disease.
#
# - **Data Preprocessing**
#   - Managed missing values
#   - Scaled numerical features using `StandardScaler`
#   - Encoded categorical variables with `LabelEncoder`
#
# - **Exploratory Data Analysis (EDA)**
#   - Used visualizations (histograms, boxplots, heatmaps) to explore feature distributions and relationships
#
# - **Model Selection & Optimization**
#   - Explored Logistic Regression, Random Forest, and XGBoost
#   - Used Grid Search for hyperparameter optimization
#
# - **Evaluation Metrics**
#   - Accuracy
#   - Precision
#   - Recall
#   - F1-score
#   - Mean Absolute Error (MAE)
#
#
# ---
#
# ## 🏁 Results Summary
#
# - **Random Forest Accuracy**: ~91%
# - **F1 Score**: 0.90
# - **Top Features**: `ChestPainType`, `ExerciseAngina`, `MaxHR`, `ST_Slope`
# ![model accuracy.PNG](data:image/png;base64,...)
# ---
#
# ## 📈 Dataset Highlights
#
# - `ASY` chest pain and `ExerciseAngina = Y` were highly correlated with heart disease diagnosis.
# - Patients with flat ST_Slope patterns and higher cholesterol were more likely to be at risk.
# - Age also emerged as a moderate risk contributor, especially beyond age 50.
#
#
# ![findings.PNG](data:image/png;base64,...)
# ---
#
# ## 🔮 Potential Improvements
#
# - Create engineered features like composite risk scores or BMI
# - Test deep learning models for more nuanced detection
# - Extend model fairness audits across intersectional demographics
#
# ---
#
# ## 🌍 Why It Matters
#
# ✅ Enables **timely intervention** and supports **non-invasive screening**
# ✅ Fosters **health equity** by removing access barriers
# ✅ Scales efficiently as a decision-support tool in primary care
#
# > *“Technology shouldn't just accelerate medicine—it should democratize it.”*
#
# ---
